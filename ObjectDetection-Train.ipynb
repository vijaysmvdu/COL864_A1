# %%
                                                                                                                                                                                                                                                                                                    from __future__ import division
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle

from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input
from keras.models import Model
from keras.utils import generic_utils
import os

from frcnn_lib import config, data_generators
from frcnn_lib import losses as losses
import frcnn_lib.roi_helpers as roi_helpers
from frcnn_lib.simple_parser import get_data

import tensorflow as tf
# used VGG model 
from frcnn_lib import vgg as nn_model

#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# Configuration 


C = config.Config()

C.use_horizontal_flips = bool(1)
C.use_vertical_flips = bool(1)
C.rot_90 = bool(1)
C.model_path = "./model_frcnn.hdf5"
C.num_rois = 32  # default value is 32
C.network = "vgg"
C.base_net_weights = nn_model.get_weight_path()

# store the meta data related to training
config_output_filename = "config.pickle"

# %%
# Read training data 
all_imgs, classes_count, class_mapping = get_data('./data/train/train.txt')
# Out:
# Parsing annotation files

# %%
if 'bg' not in classes_count:
    classes_count['bg'] = 0
    class_mapping['bg'] = len(class_mapping)

C.class_mapping = class_mapping
inv_map = {v: k for k, v in class_mapping.items()}
print('Training images per class:')
pprint.pprint(classes_count)
print('Num classes (including bg) = {}'.format(len(classes_count)))
# Out:
# Training images per class:
# {'bg': 0, 'cow': 1375, 'dog': 1147}
# Num classes (including bg) = 3

# %%
# training related metadata
with open(config_output_filename, 'wb') as config_f:
    pickle.dump(C,config_f)
    print('Config has been written to {}, and can be loaded when testing to ensure correct results'.format(config_output_filename))
# Out:
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results

# %%
# Image preprocessing

# suffle all images
random.shuffle(all_imgs)
num_imgs = len(all_imgs)
train_imgs = [s for s in all_imgs if s['imageset'] == 'trainval']
val_imgs = [s for s in all_imgs if s['imageset'] == 'test']

print('Num train samples {}'.format(len(train_imgs)))
print('Num val samples {}'.format(len(val_imgs)))

# data generator
data_gen_train = data_generators.get_anchor_gt(train_imgs, classes_count, C, nn_model.get_img_output_length, K.image_dim_ordering(), mode='train')
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, C, nn_model.get_img_output_length,K.image_dim_ordering(), mode='val')

if K.image_dim_ordering() == 'th':
    nput_shape_img = (3, None, None)
else:
    input_shape_img = (None, None, 3)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))
# Out:
# Num train samples 2038
# Num val samples 51

# %%
# define base network (VGG)
shared_layers = nn_model.nn_base(img_input, trainable=True)

# %%
# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn = nn_model.rpn(shared_layers, num_anchors)
classifier = nn_model.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)
model_rpn = Model(img_input, rpn[:2])
model_classifier = Model([img_input, roi_input], classifier)
# this is a model that holds both the RPN and the classifier, used to load/save weights for the models
model_all = Model([img_input, roi_input], rpn[:2] + classifier)

# %%
# load weight
print('loading weights from {}'.format(C.base_net_weights))
model_rpn.load_weights(C.base_net_weights, by_name=True)
model_classifier.load_weights(C.base_net_weights, by_name=True)
# Out:
# loading weights from vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %%
# compile model
lr = 0.00001

model_rpn.compile(optimizer=Adam(lr), loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])

model_classifier.compile(optimizer= Adam(lr), loss=[losses.class_loss_cls, losses.class_loss_regr(len(classes_count)-1)], metrics={'dense_class_{}'.format(len(classes_count)): 'accuracy'})

model_all.compile(optimizer='sgd', loss='mae')

# %%
def start_training(num_epochs, epoch_length , class_mapping, C, K,  data_gen_train, model_rpn, model_classifier,model_all):
    
    iter_num = 0
    losses = np.zeros((epoch_length, 5))
    rpn_accuracy_rpn_monitor = []
    rpn_accuracy_for_epoch = []
    start_time = time.time()
    best_loss = np.Inf
    class_mapping_inv = {v: k for k, v in class_mapping.items()}
    
    print('Starting training')

    vis = True

    for epoch_num in range(num_epochs):

        progbar = generic_utils.Progbar(epoch_length)
        print('Epoch {}/{}'.format(epoch_num + 1, num_epochs))

        while True:
            try:

                if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
                    mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
                    rpn_accuracy_rpn_monitor = []
                    print('Average number of overlapping bounding boxes from RPN = {} for {} previous iterations'.format(mean_overlapping_bboxes, epoch_length))
                    if mean_overlapping_bboxes == 0:
                        print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

                X, Y, img_data = next(data_gen_train)

                loss_rpn = model_rpn.train_on_batch(X, Y)

                P_rpn = model_rpn.predict_on_batch(X)

                R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, K.image_dim_ordering(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
                # note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
                X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)

                if X2 is None:
                    rpn_accuracy_rpn_monitor.append(0)
                    rpn_accuracy_for_epoch.append(0)
                    continue

                neg_samples = np.where(Y1[0, :, -1] == 1)
                pos_samples = np.where(Y1[0, :, -1] == 0)

                if len(neg_samples) > 0:
                    neg_samples = neg_samples[0]
                else:
                    neg_samples = []

                if len(pos_samples) > 0:
                    pos_samples = pos_samples[0]
                else:
                    pos_samples = []

                rpn_accuracy_rpn_monitor.append(len(pos_samples))
                rpn_accuracy_for_epoch.append((len(pos_samples)))

                if C.num_rois > 1:
                    if len(pos_samples) < C.num_rois//2:
                        selected_pos_samples = pos_samples.tolist()
                    else:
                        selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
                    try:
                        selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
                    except:
                        selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()

                    sel_samples = selected_pos_samples + selected_neg_samples
                else:
                    # in the extreme case where num_rois = 1, we pick a random pos or neg sample
                    selected_pos_samples = pos_samples.tolist()
                    selected_neg_samples = neg_samples.tolist()
                    if np.random.randint(0, 2):
                        sel_samples = random.choice(neg_samples)
                    else:
                        sel_samples = random.choice(pos_samples)

                loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

                losses[iter_num, 0] = loss_rpn[1]
                losses[iter_num, 1] = loss_rpn[2]

                losses[iter_num, 2] = loss_class[1]
                losses[iter_num, 3] = loss_class[2]
                losses[iter_num, 4] = loss_class[3]

                iter_num += 1

                progbar.update(iter_num, [('rpn_cls', np.mean(losses[:iter_num, 0])), ('rpn_regr', np.mean(losses[:iter_num, 1])),
                                          ('detector_cls', np.mean(losses[:iter_num, 2])), ('detector_regr', np.mean(losses[:iter_num, 3]))])

                if iter_num == epoch_length:
                    loss_rpn_cls = np.mean(losses[:, 0])
                    loss_rpn_regr = np.mean(losses[:, 1])
                    loss_class_cls = np.mean(losses[:, 2])
                    loss_class_regr = np.mean(losses[:, 3])
                    class_acc = np.mean(losses[:, 4])

                    mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
                    rpn_accuracy_for_epoch = []

                    if C.verbose:
                        print('Mean number of bounding boxes from RPN overlapping ground truth boxes: {}'.format(mean_overlapping_bboxes))
                        print('Classifier accuracy for bounding boxes from RPN: {}'.format(class_acc))
                        print('Loss RPN classifier: {}'.format(loss_rpn_cls))
                        print('Loss RPN regression: {}'.format(loss_rpn_regr))
                        print('Loss Detector classifier: {}'.format(loss_class_cls))
                        print('Loss Detector regression: {}'.format(loss_class_regr))
                        print('Elapsed time: {}'.format(time.time() - start_time))
                        model_all.save_weights("epoch"+str(epoch_num)+"_model_frcnn.hdf5")

                    curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
                    iter_num = 0
                    start_time = time.time()

                    if curr_loss < best_loss:
                        if C.verbose:
                            print('Total loss decreased from {} to {}, saving weights'.format(best_loss,curr_loss))
                        best_loss = curr_loss
                        model_all.save_weights(C.model_path)

                    break

            except Exception as e:
                print('Exception: {}'.format(e))
                continue

    print('Training complete, exiting.')

# %%
# Start training 

epoch_length = 200
num_epochs = 100

start_training(num_epochs, epoch_length, class_mapping, C, K,  data_gen_train, model_rpn, model_classifier,model_all)
# Out:
# Starting training
# Epoch 1/100
# 181/200 [==========================>...] - ETA: 24s - rpn_cls: 4.6740 - rpn_regr: 0.1732 - detector_cls: 0.4400 - detector_regr: 0.2924Average number of overlapping bounding boxes from RPN = 2.975 for 200 previous iterations
# 200/200 [==============================] - 251s 1s/step - rpn_cls: 4.6337 - rpn_regr: 0.1733 - detector_cls: 0.4338 - detector_regr: 0.2897
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.140909090909091
# Classifier accuracy for bounding boxes from RPN: 0.8940625
# Loss RPN classifier: 4.237836672208325
# Loss RPN regression: 0.17595094898715616
# Loss Detector classifier: 0.37179569419140934
# Loss Detector regression: 0.2626566331833601
# Elapsed time: 251.2884180545807
# Total loss decreased from inf to 5.0482399485702505, saving weights
# Epoch 2/100
# 173/200 [========================>.....] - ETA: 30s - rpn_cls: 3.8395 - rpn_regr: 0.1492 - detector_cls: 0.3616 - detector_regr: 0.2662Average number of overlapping bounding boxes from RPN = 4.28 for 200 previous iterations
# 200/200 [==============================] - 229s 1s/step - rpn_cls: 3.7963 - rpn_regr: 0.1499 - detector_cls: 0.3657 - detector_regr: 0.2673
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.5048076923076925
# Classifier accuracy for bounding boxes from RPN: 0.86203125
# Loss RPN classifier: 3.452480220797872
# Loss RPN regression: 0.1535650036390871
# Loss Detector classifier: 0.39364021404791855
# Loss Detector regression: 0.2753786526620388
# Elapsed time: 229.40715098381042
# Total loss decreased from 5.0482399485702505 to 4.275064091146916, saving weights
# Epoch 3/100
# 169/200 [========================>.....] - ETA: 34s - rpn_cls: 2.9153 - rpn_regr: 0.1440 - detector_cls: 0.3969 - detector_regr: 0.2848Average number of overlapping bounding boxes from RPN = 6.14 for 200 previous iterations
# 200/200 [==============================] - 223s 1s/step - rpn_cls: 2.9030 - rpn_regr: 0.1427 - detector_cls: 0.4083 - detector_regr: 0.2923
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 6.679802955665025
# Classifier accuracy for bounding boxes from RPN: 0.80234375
# Loss RPN classifier: 2.8334555965249217
# Loss RPN regression: 0.13235026013571768
# Loss Detector classifier: 0.4830347124871332
# Loss Detector regression: 0.34192553207278253
# Elapsed time: 226.9509961605072
# Total loss decreased from 4.275064091146916 to 3.790766101220555, saving weights
# Epoch 4/100
# 161/200 [=======================>......] - ETA: 43s - rpn_cls: 2.2013 - rpn_regr: 0.1238 - detector_cls: 0.5822 - detector_regr: 0.3864Average number of overlapping bounding boxes from RPN = 7.685 for 200 previous iterations
# 200/200 [==============================] - 225s 1s/step - rpn_cls: 2.2378 - rpn_regr: 0.1257 - detector_cls: 0.5702 - detector_regr: 0.3815
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.014354066985646
# Classifier accuracy for bounding boxes from RPN: 0.78359375
# Loss RPN classifier: 2.4200859932446077
# Loss RPN regression: 0.13298144354484975
# Loss Detector classifier: 0.5149465770367533
# Loss Detector regression: 0.3530746913701296
# Elapsed time: 229.06295585632324
# Total loss decreased from 3.790766101220555 to 3.42108870519634, saving weights
# Epoch 5/100
# 136/200 [===================>..........] - ETA: 1:13 - rpn_cls: 3.1744 - rpn_regr: 0.1509 - detector_cls: 0.5049 - detector_regr: 0.3446Exception: 'a' cannot be empty unless no samples are taken
# 150/200 [=====================>........] - ETA: 57s - rpn_cls: 3.1289 - rpn_regr: 0.1495 - detector_cls: 0.5046 - detector_regr: 0.3463Average number of overlapping bounding boxes from RPN = 6.905 for 200 previous iterations
# 200/200 [==============================] - 228s 1s/step - rpn_cls: 2.9878 - rpn_regr: 0.1457 - detector_cls: 0.5022 - detector_regr: 0.3501
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.516587677725118
# Classifier accuracy for bounding boxes from RPN: 0.78375
# Loss RPN classifier: 2.5201632568096284
# Loss RPN regression: 0.1310058145946823
# Loss Detector classifier: 0.502512031616643
# Loss Detector regression: 0.36338473357260226
# Elapsed time: 231.99355697631836
# Epoch 6/100
# 149/200 [=====================>........] - ETA: 55s - rpn_cls: 2.3590 - rpn_regr: 0.1258 - detector_cls: 0.4894 - detector_regr: 0.3383Average number of overlapping bounding boxes from RPN = 7.655 for 200 previous iterations
# 200/200 [==============================] - 221s 1s/step - rpn_cls: 2.3764 - rpn_regr: 0.1267 - detector_cls: 0.4864 - detector_regr: 0.3387
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.391089108910891
# Classifier accuracy for bounding boxes from RPN: 0.795625
# Loss RPN classifier: 2.404144450634417
# Loss RPN regression: 0.1296521273488179
# Loss Detector classifier: 0.48518973047554026
# Loss Detector regression: 0.34452167138457296
# Elapsed time: 221.16506481170654
# Total loss decreased from 3.42108870519634 to 3.363507979843348, saving weights
# Epoch 7/100
# 143/200 [====================>.........] - ETA: 1:03 - rpn_cls: 2.5846 - rpn_regr: 0.1429 - detector_cls: 0.4614 - detector_regr: 0.3835Average number of overlapping bounding boxes from RPN = 7.885 for 200 previous iterations
# 200/200 [==============================] - 224s 1s/step - rpn_cls: 2.5734 - rpn_regr: 0.1412 - detector_cls: 0.4684 - detector_regr: 0.3739
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.268292682926829
# Classifier accuracy for bounding boxes from RPN: 0.77671875
# Loss RPN classifier: 2.479226121506867
# Loss RPN regression: 0.13803646665997804
# Loss Detector classifier: 0.4932383617723826
# Loss Detector regression: 0.3512686645612121
# Elapsed time: 228.61342000961304
# Epoch 8/100
# 142/200 [====================>.........] - ETA: 1:02 - rpn_cls: 2.1946 - rpn_regr: 0.1320 - detector_cls: 0.4952 - detector_regr: 0.3187Average number of overlapping bounding boxes from RPN = 8.33 for 200 previous iterations
# 200/200 [==============================] - 217s 1s/step - rpn_cls: 2.2260 - rpn_regr: 0.1291 - detector_cls: 0.4852 - detector_regr: 0.3134
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.08955223880597
# Classifier accuracy for bounding boxes from RPN: 0.80203125
# Loss RPN classifier: 2.2136455767581835
# Loss RPN regression: 0.11852218085201457
# Loss Detector classifier: 0.4574571887725324
# Loss Detector regression: 0.3115161257237196
# Elapsed time: 216.59092140197754
# Total loss decreased from 3.363507979843348 to 3.1011410721064503, saving weights
# Epoch 9/100
# 140/200 [====================>.........] - ETA: 1:05 - rpn_cls: 2.0816 - rpn_regr: 0.1006 - detector_cls: 0.5253 - detector_regr: 0.3386Average number of overlapping bounding boxes from RPN = 8.98 for 200 previous iterations
# 200/200 [==============================] - 219s 1s/step - rpn_cls: 2.0325 - rpn_regr: 0.1022 - detector_cls: 0.5206 - detector_regr: 0.3335
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.719211822660098
# Classifier accuracy for bounding boxes from RPN: 0.765625
# Loss RPN classifier: 1.921966630943775
# Loss RPN regression: 0.10957830096944235
# Loss Detector classifier: 0.49788879592320884
# Loss Detector regression: 0.3250545150414109
# Elapsed time: 223.91899633407593
# Total loss decreased from 3.1011410721064503 to 2.8544882428778373, saving weights
# Epoch 10/100
# 138/200 [===================>..........] - ETA: 1:08 - rpn_cls: 2.4445 - rpn_regr: 0.1207 - detector_cls: 0.4447 - detector_regr: 0.3037Average number of overlapping bounding boxes from RPN = 8.22 for 200 previous iterations
# 200/200 [==============================] - 222s 1s/step - rpn_cls: 2.3773 - rpn_regr: 0.1200 - detector_cls: 0.4481 - detector_regr: 0.3040
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.297029702970297
# Classifier accuracy for bounding boxes from RPN: 0.79328125
# Loss RPN classifier: 2.1594818096536645
# Loss RPN regression: 0.11747562749020289
# Loss Detector classifier: 0.45750955820083616
# Loss Detector regression: 0.30440137488767505
# Elapsed time: 226.46601271629333
# Epoch 11/100
# 135/200 [===================>..........] - ETA: 1:10 - rpn_cls: 2.1271 - rpn_regr: 0.1097 - detector_cls: 0.5172 - detector_regr: 0.3258Average number of overlapping bounding boxes from RPN = 8.975 for 200 previous iterations
# 200/200 [==============================] - 219s 1s/step - rpn_cls: 2.0614 - rpn_regr: 0.1102 - detector_cls: 0.5038 - detector_regr: 0.3220
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.648514851485148
# Classifier accuracy for bounding boxes from RPN: 0.78140625
# Loss RPN classifier: 1.9180448158526557
# Loss RPN regression: 0.11345537960878574
# Loss Detector classifier: 0.4737733021937311
# Loss Detector regression: 0.3064168343320489
# Elapsed time: 218.56632471084595
# Total loss decreased from 2.8544882428778373 to 2.8116903319872213, saving weights
# Epoch 12/100
# 134/200 [===================>..........] - ETA: 1:13 - rpn_cls: 1.6107 - rpn_regr: 0.1111 - detector_cls: 0.4464 - detector_regr: 0.3054Average number of overlapping bounding boxes from RPN = 8.865 for 200 previous iterations
# 200/200 [==============================] - 224s 1s/step - rpn_cls: 1.7346 - rpn_regr: 0.1104 - detector_cls: 0.4510 - detector_regr: 0.3040
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.223880597014926
# Classifier accuracy for bounding boxes from RPN: 0.78421875
# Loss RPN classifier: 1.9113121342960324
# Loss RPN regression: 0.10816463206894696
# Loss Detector classifier: 0.46324184355333275
# Loss Detector regression: 0.3002480474114418
# Elapsed time: 228.12019205093384
# Total loss decreased from 2.8116903319872213 to 2.7829666573297542, saving weights
# Epoch 13/100
# 132/200 [==================>...........] - ETA: 1:15 - rpn_cls: 2.0079 - rpn_regr: 0.1130 - detector_cls: 0.4388 - detector_regr: 0.2709Average number of overlapping bounding boxes from RPN = 9.605 for 200 previous iterations
# 200/200 [==============================] - 224s 1s/step - rpn_cls: 1.9192 - rpn_regr: 0.1139 - detector_cls: 0.4392 - detector_regr: 0.2777
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.768472906403941
# Classifier accuracy for bounding boxes from RPN: 0.8078125
# Loss RPN classifier: 1.764616869797793
# Loss RPN regression: 0.1160142078739591
# Loss Detector classifier: 0.4332680487632751
# Loss Detector regression: 0.30106463812291623
# Elapsed time: 227.94338512420654
# Total loss decreased from 2.7829666573297542 to 2.614963764557943, saving weights
# Epoch 14/100
# 128/200 [==================>...........] - ETA: 1:20 - rpn_cls: 1.7056 - rpn_regr: 0.1221 - detector_cls: 0.4265 - detector_regr: 0.3012Average number of overlapping bounding boxes from RPN = 8.77 for 200 previous iterations
# 200/200 [==============================] - 226s 1s/step - rpn_cls: 1.7709 - rpn_regr: 0.1219 - detector_cls: 0.4316 - detector_regr: 0.2997
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.264705882352942
# Classifier accuracy for bounding boxes from RPN: 0.7996875
# Loss RPN classifier: 1.9272988420018924
# Loss RPN regression: 0.11719647564226761
# Loss Detector classifier: 0.4503327585229999
# Loss Detector regression: 0.3054320029914379
# Elapsed time: 230.2735984325409
# Epoch 15/100
# 124/200 [=================>............] - ETA: 1:24 - rpn_cls: 1.7309 - rpn_regr: 0.1235 - detector_cls: 0.4420 - detector_regr: 0.2920Average number of overlapping bounding boxes from RPN = 10.11 for 200 previous iterations
# 200/200 [==============================] - 222s 1s/step - rpn_cls: 1.7477 - rpn_regr: 0.1181 - detector_cls: 0.4334 - detector_regr: 0.2897
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.757425742574258
# Classifier accuracy for bounding boxes from RPN: 0.81609375
# Loss RPN classifier: 1.7897317658248972
# Loss RPN regression: 0.10838356987806037
# Loss Detector classifier: 0.4250705091515556
# Loss Detector regression: 0.28328865407034753
# Elapsed time: 221.97859573364258
# Total loss decreased from 2.614963764557943 to 2.6064744989248605, saving weights
# Epoch 16/100
# 124/200 [=================>............] - ETA: 1:23 - rpn_cls: 1.7540 - rpn_regr: 0.1284 - detector_cls: 0.4333 - detector_regr: 0.2954Average number of overlapping bounding boxes from RPN = 9.16 for 200 previous iterations
# 200/200 [==============================] - 223s 1s/step - rpn_cls: 1.7976 - rpn_regr: 0.1259 - detector_cls: 0.4306 - detector_regr: 0.2928
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.34
# Classifier accuracy for bounding boxes from RPN: 0.8009375
# Loss RPN classifier: 1.8293029031340335
# Loss RPN regression: 0.12103456263896079
# Loss Detector classifier: 0.43833264560671525
# Loss Detector regression: 0.2885718346759677
# Elapsed time: 226.95038318634033
# Epoch 17/100
# 123/200 [=================>............] - ETA: 1:24 - rpn_cls: 1.8777 - rpn_regr: 0.0942 - detector_cls: 0.4351 - detector_regr: 0.2730Average number of overlapping bounding boxes from RPN = 9.83 for 200 previous iterations
# 200/200 [==============================] - 223s 1s/step - rpn_cls: 1.9785 - rpn_regr: 0.0973 - detector_cls: 0.4242 - detector_regr: 0.2673
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.557213930348258
# Classifier accuracy for bounding boxes from RPN: 0.81734375
# Loss RPN classifier: 2.1700551672494317
# Loss RPN regression: 0.10657847619848326
# Loss Detector classifier: 0.4024440541048534
# Loss Detector regression: 0.2612813127413392
# Elapsed time: 222.6574079990387
# Epoch 18/100
# 122/200 [=================>............] - ETA: 1:26 - rpn_cls: 1.5666 - rpn_regr: 0.0894 - detector_cls: 0.3992 - detector_regr: 0.2249Average number of overlapping bounding boxes from RPN = 9.16 for 200 previous iterations
# 200/200 [==============================] - 222s 1s/step - rpn_cls: 1.5683 - rpn_regr: 0.0891 - detector_cls: 0.4035 - detector_regr: 0.2363
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.589108910891088
# Classifier accuracy for bounding boxes from RPN: 0.81421875
# Loss RPN classifier: 1.5591712805435807
# Loss RPN regression: 0.0910172003088519
# Loss Detector classifier: 0.41213203394319864
# Loss Detector regression: 0.2635326491482556
# Elapsed time: 222.0679407119751
# Total loss decreased from 2.6064744989248605 to 2.325853163943887, saving weights
# Epoch 19/100
# 120/200 [=================>............] - ETA: 1:27 - rpn_cls: 1.3448 - rpn_regr: 0.1037 - detector_cls: 0.4227 - detector_regr: 0.3148Average number of overlapping bounding boxes from RPN = 11.275 for 200 previous iterations
# 200/200 [==============================] - 216s 1s/step - rpn_cls: 1.3595 - rpn_regr: 0.1013 - detector_cls: 0.4151 - detector_regr: 0.3063
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.114427860696518
# Classifier accuracy for bounding boxes from RPN: 0.81140625
# Loss RPN classifier: 1.4291920979555324
# Loss RPN regression: 0.09838783012353815
# Loss Detector classifier: 0.40380060887429864
# Loss Detector regression: 0.28882101403549315
# Elapsed time: 220.33868718147278
# Total loss decreased from 2.325853163943887 to 2.2202015509888624, saving weights
# Epoch 20/100
# 120/200 [=================>............] - ETA: 1:25 - rpn_cls: 1.7602 - rpn_regr: 0.1000 - detector_cls: 0.4006 - detector_regr: 0.2531Average number of overlapping bounding boxes from RPN = 10.195 for 200 previous iterations
# 200/200 [==============================] - 215s 1s/step - rpn_cls: 1.6550 - rpn_regr: 0.1018 - detector_cls: 0.4169 - detector_regr: 0.2621
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.595
# Classifier accuracy for bounding boxes from RPN: 0.795625
# Loss RPN classifier: 1.4898834807526902
# Loss RPN regression: 0.1047385089052841
# Loss Detector classifier: 0.4373999599169474
# Loss Detector regression: 0.27197174126282336
# Elapsed time: 219.60438418388367
# Epoch 21/100
# 120/200 [=================>............] - ETA: 1:28 - rpn_cls: 1.2013 - rpn_regr: 0.1112 - detector_cls: 0.4297 - detector_regr: 0.2681Average number of overlapping bounding boxes from RPN = 10.69 for 200 previous iterations
# 200/200 [==============================] - 217s 1s/step - rpn_cls: 1.2485 - rpn_regr: 0.1090 - detector_cls: 0.4287 - detector_regr: 0.2758
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.32
# Classifier accuracy for bounding boxes from RPN: 0.81
# Loss RPN classifier: 1.316161823454296
# Loss RPN regression: 0.10295308357803151
# Loss Detector classifier: 0.42953722392529015
# Loss Detector regression: 0.287823451757431
# Elapsed time: 217.2508578300476
# Total loss decreased from 2.2202015509888624 to 2.1364755827150486, saving weights
# Epoch 22/100
# 120/200 [=================>............] - ETA: 1:26 - rpn_cls: 1.4519 - rpn_regr: 0.1228 - detector_cls: 0.4153 - detector_regr: 0.2737Average number of overlapping bounding boxes from RPN = 10.56 for 200 previous iterations
# 200/200 [==============================] - 217s 1s/step - rpn_cls: 1.4232 - rpn_regr: 0.1156 - detector_cls: 0.4194 - detector_regr: 0.2723
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.43
# Classifier accuracy for bounding boxes from RPN: 0.80921875
# Loss RPN classifier: 1.3370854190108894
# Loss RPN regression: 0.10186806134763174
# Loss Detector classifier: 0.4295893381116912
# Loss Detector regression: 0.2705529150087386
# Elapsed time: 220.99688935279846
# Epoch 23/100
# 119/200 [================>.............] - ETA: 1:28 - rpn_cls: 1.4033 - rpn_regr: 0.0966 - detector_cls: 0.4091 - detector_regr: 0.2579Average number of overlapping bounding boxes from RPN = 11.245 for 200 previous iterations
# 200/200 [==============================] - 220s 1s/step - rpn_cls: 1.3787 - rpn_regr: 0.0994 - detector_cls: 0.4119 - detector_regr: 0.2640
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.782178217821782
# Classifier accuracy for bounding boxes from RPN: 0.80484375
# Loss RPN classifier: 1.3465508085153988
# Loss RPN regression: 0.10831288642482832
# Loss Detector classifier: 0.4189660514215939
# Loss Detector regression: 0.26480225307866934
# Elapsed time: 219.60520935058594
# Epoch 24/100
# 118/200 [================>.............] - ETA: 1:30 - rpn_cls: 1.7510 - rpn_regr: 0.0991 - detector_cls: 0.4475 - detector_regr: 0.2760Average number of overlapping bounding boxes from RPN = 10.375 for 200 previous iterations
# 200/200 [==============================] - 217s 1s/step - rpn_cls: 1.6744 - rpn_regr: 0.1017 - detector_cls: 0.4335 - detector_regr: 0.2690
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.56
# Classifier accuracy for bounding boxes from RPN: 0.81
# Loss RPN classifier: 1.619009727215781
# Loss RPN regression: 0.10327833374496549
# Loss Detector classifier: 0.4125192953195074
# Loss Detector regression: 0.25235910462215544
# Elapsed time: 217.2094588279724
# Epoch 25/100
# 118/200 [================>.............] - ETA: 1:30 - rpn_cls: 1.5386 - rpn_regr: 0.1035 - detector_cls: 0.3813 - detector_regr: 0.2406Average number of overlapping bounding boxes from RPN = 10.655 for 200 previous iterations
# 200/200 [==============================] - 219s 1s/step - rpn_cls: 1.5227 - rpn_regr: 0.1018 - detector_cls: 0.3935 - detector_regr: 0.2417
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.4
# Classifier accuracy for bounding boxes from RPN: 0.80734375
# Loss RPN classifier: 1.4617658208100037
# Loss RPN regression: 0.10187355437024963
# Loss Detector classifier: 0.42205961673986164
# Loss Detector regression: 0.24918426102027297
# Elapsed time: 218.86688089370728
# Epoch 26/100
# 118/200 [================>.............] - ETA: 1:29 - rpn_cls: 1.5384 - rpn_regr: 0.1162 - detector_cls: 0.3799 - detector_regr: 0.2754Average number of overlapping bounding boxes from RPN = 11.785 for 200 previous iterations
# 200/200 [==============================] - 220s 1s/step - rpn_cls: 1.5150 - rpn_regr: 0.1141 - detector_cls: 0.3833 - detector_regr: 0.2678
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.01980198019802
# Classifier accuracy for bounding boxes from RPN: 0.820625
# Loss RPN classifier: 1.5340291514331752
# Loss RPN regression: 0.11456735518528148
# Loss Detector classifier: 0.39597935616737234
# Loss Detector regression: 0.2609736477024853
# Elapsed time: 219.5844235420227
# Epoch 27/100
# 116/200 [================>.............] - ETA: 1:32 - rpn_cls: 1.3047 - rpn_regr: 0.0899 - detector_cls: 0.4002 - detector_regr: 0.2385Average number of overlapping bounding boxes from RPN = 10.85 for 200 previous iterations
# 200/200 [==============================] - 220s 1s/step - rpn_cls: 1.3305 - rpn_regr: 0.0980 - detector_cls: 0.3973 - detector_regr: 0.2444
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.375
# Classifier accuracy for bounding boxes from RPN: 0.8178125
# Loss RPN classifier: 1.3294905494725293
# Loss RPN regression: 0.10606763849733397
# Loss Detector classifier: 0.39807978250435555
# Loss Detector regression: 0.25772106962278485
# Elapsed time: 220.46726822853088
# Total loss decreased from 2.1364755827150486 to 2.0913590400970037, saving weights
# Epoch 28/100
# 116/200 [================>.............] - ETA: 1:30 - rpn_cls: 1.0417 - rpn_regr: 0.0854 - detector_cls: 0.4189 - detector_regr: 0.2926Average number of overlapping bounding boxes from RPN = 11.43 for 200 previous iterations
# 200/200 [==============================] - 217s 1s/step - rpn_cls: 1.0858 - rpn_regr: 0.0898 - detector_cls: 0.4160 - detector_regr: 0.2819
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.84
# Classifier accuracy for bounding boxes from RPN: 0.816875
# Loss RPN classifier: 1.2060829057489584
# Loss RPN regression: 0.09395800053956918
# Loss Detector classifier: 0.40131499503506346
# Loss Detector regression: 0.2575005786772817
# Elapsed time: 221.06422638893127
# Total loss decreased from 2.0913590400970037 to 1.9588564800008728, saving weights
# Epoch 29/100
# 116/200 [================>.............] - ETA: 1:31 - rpn_cls: 1.2581 - rpn_regr: 0.0888 - detector_cls: 0.3852 - detector_regr: 0.2692Average number of overlapping bounding boxes from RPN = 10.89 for 200 previous iterations
# 200/200 [==============================] - 219s 1s/step - rpn_cls: 1.1968 - rpn_regr: 0.0900 - detector_cls: 0.3861 - detector_regr: 0.2692
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.08
# Classifier accuracy for bounding boxes from RPN: 0.82375
# Loss RPN classifier: 1.0598113359190429
# Loss RPN regression: 0.08970739902579225
# Loss Detector classifier: 0.3982881113048643
# Loss Detector regression: 0.2684437775984406
# Elapsed time: 222.99164128303528
# Total loss decreased from 1.9588564800008728 to 1.81625062384814, saving weights
# Epoch 30/100
# 116/200 [================>.............] - ETA: 1:31 - rpn_cls: 0.9670 - rpn_regr: 0.0802 - detector_cls: 0.3760 - detector_regr: 0.2280Average number of overlapping bounding boxes from RPN = 11.68 for 200 previous iterations
# 200/200 [==============================] - 219s 1s/step - rpn_cls: 0.9626 - rpn_regr: 0.0835 - detector_cls: 0.3841 - detector_regr: 0.2359
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.960199004975124
# Classifier accuracy for bounding boxes from RPN: 0.81765625
# Loss RPN classifier: 0.9822682778645386
# Loss RPN regression: 0.08891326920303982
# Loss Detector classifier: 0.39791090665385126
# Loss Detector regression: 0.25429418293759226
# Elapsed time: 223.424907207489
# Total loss decreased from 1.81625062384814 to 1.723386636659022, saving weights
# Epoch 31/100
# 115/200 [================>.............] - ETA: 1:33 - rpn_cls: 1.1239 - rpn_regr: 0.1092 - detector_cls: 0.3673 - detector_regr: 0.2393Average number of overlapping bounding boxes from RPN = 11.645 for 200 previous iterations
# 200/200 [==============================] - 221s 1s/step - rpn_cls: 1.1253 - rpn_regr: 0.1084 - detector_cls: 0.3796 - detector_regr: 0.2458
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.795
# Classifier accuracy for bounding boxes from RPN: 0.83359375
# Loss RPN classifier: 1.1126888669241644
# Loss RPN regression: 0.10691259954706765
# Loss Detector classifier: 0.38089239165303296
# Loss Detector regression: 0.2481150946393609
# Elapsed time: 225.027574300766
# Epoch 32/100
# 114/200 [================>.............] - ETA: 1:34 - rpn_cls: 0.9579 - rpn_regr: 0.0867 - detector_cls: 0.3894 - detector_regr: 0.2284Average number of overlapping bounding boxes from RPN = 10.3 for 200 previous iterations
# 197/200 [============================>.] - ETA: 3s - rpn_cls: 0.9764 - rpn_regr: 0.0898 - detector_cls: 0.3888 - detector_regr: 0.2306

# %%
# Testing
